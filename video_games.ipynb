# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyaagarwal178/video_games_prediction/blob/main/video_games.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import neccessary libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Read and display csv files**

# %%
games = pd.read_csv('video_games_sales.csv')
games.head(3)
# Out:
#                 Name Platform  Year_of_Release     Genre Publisher  NA_Sales  \
# 0         Wii Sports      Wii           2006.0    Sports  Nintendo     41.36
# 1  Super Mario Bros.      NES           1985.0  Platform  Nintendo     29.08
# 2     Mario Kart Wii      Wii           2008.0    Racing  Nintendo     15.68
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 0     28.96      3.77         8.45         82.53          76.0          51.0
# 1      3.58      6.81         0.77         40.24           NaN           NaN
# 2     12.76      3.79         3.29         35.52          82.0          73.0
#
#   User_Score  User_Count Developer Rating
# 0          8       322.0  Nintendo      E
# 1        NaN         NaN       NaN    NaN
# 2        8.3       709.0  Nintendo      E

# %% [markdown]
# **Display shape of the file**

# %%
games.shape
# Out:
# (16719, 16)

# %% [markdown]
# **Count the number of missing (null or NaN) values in each column**

# %%
games.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
games['Rating'][1] == np.nan

# %% [markdown]
# **In the provided code snippet, you are creating a new DataFrame called games_filtered by selecting rows from the original DataFrame games where the 'Rating' column is not NaN. Then, you are checking for missing values in the games_filtered DataFrame using the isnull().sum() method.**

# %%
games_filtered = games[games['Rating'].notna()]
games_filtered.isnull().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release     181
# Genre                 0
# Publisher             7
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       1896
# Critic_Count       1896
# User_Score           71
# User_Count         2446
# Developer             0
# Rating                0
# dtype: int64

# %% [markdown]
# **Display shape of the file**

# %%
games_filtered.shape

# %% [markdown]
# **Obtain a count of unique values in the column**

# %%
games_filtered['Year_of_Release'].value_counts()
# Out:
# 2009.0    1011
# 2008.0     981
# 2007.0     821
# 2010.0     799
# 2005.0     706
# 2011.0     703
# 2006.0     678
# 2002.0     655
# 2003.0     613
# 2004.0     598
# 2012.0     355
# 2014.0     345
# 2001.0     339
# 2013.0     316
# 2015.0     315
# 2016.0     280
# 2000.0     148
# 1999.0      42
# 1998.0      32
# 1997.0      19
# 1996.0       7
# 1992.0       2
# 1994.0       1
# 2020.0       1
# 1985.0       1
# 1988.0       1
# Name: Year_of_Release, dtype: int64

# %%
games_filtered['Publisher'].value_counts()
# Out:
# Electronic Arts                 1139
# Ubisoft                          784
# Activision                       781
# THQ                              532
# Konami Digital Entertainment     382
#                                 ...
# Mercury Games                      1
# Pacific Century Cyber Works        1
# iWin                               1
# NDA Productions                    1
# Mentor Interactive                 1
# Name: Publisher, Length: 332, dtype: int64

# %%
games_filtered['User_Score'].value_counts()
# Out:
# tbd    2375
# 7.8     322
# 8       286
# 8.2     278
# 8.5     252
#        ...
# 1.1       2
# 1.9       2
# 9.6       2
# 0         1
# 9.7       1
# Name: User_Score, Length: 96, dtype: int64

# %% [markdown]
# **Handle missing values in the DataFrame df4**

# %%
df1 = games_filtered[games_filtered['Critic_Score'].notna()]
df2 = df1[df1['Critic_Score'].notna()]
df3 = df2[df2['Critic_Count'].notna()]
df4 = df3[df3['User_Count'].notna()]

df4['Year_of_Release'].fillna(2009.0, inplace=True)
df4['Publisher'].fillna("Electronic Arts", inplace = True)
df4['User_Score'].fillna("tbd", inplace =True)

df4.isnull().sum()
# Out:
# <ipython-input-9-448842fa303c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['Year_of_Release'].fillna(2009.0, inplace=True)
# <ipython-input-9-448842fa303c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['Publisher'].fillna("Electronic Arts", inplace = True)
# <ipython-input-9-448842fa303c>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['User_Score'].fillna("tbd", inplace =True)
# Name               0
# Platform           0
# Year_of_Release    0
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       0
# Critic_Count       0
# User_Score         0
# User_Count         0
# Developer          0
# Rating             0
# dtype: int64

# %% [markdown]
# **Display the shape**

# %%
df4.shape

# %% [markdown]
# **Describe the field**

# %%
df4.describe()
# Out:
#        Year_of_Release     NA_Sales     EU_Sales     JP_Sales  Other_Sales  \
# count      6947.000000  6947.000000  6947.000000  6947.000000  6947.000000
# mean       2007.464517     0.392840     0.234648     0.063236     0.082189
# std           4.179323     0.961157     0.682293     0.285257     0.267832
# min        1985.000000     0.000000     0.000000     0.000000     0.000000
# 25%        2004.000000     0.060000     0.020000     0.000000     0.010000
# 50%        2007.000000     0.150000     0.060000     0.000000     0.020000
# 75%        2010.000000     0.390000     0.210000     0.010000     0.070000
# max        2016.000000    41.360000    28.960000     6.500000    10.570000
#
#        Global_Sales  Critic_Score  Critic_Count    User_Count
# count   6947.000000   6947.000000   6947.000000   6947.000000
# mean       0.773098     70.263567     28.873615    173.821362
# std        1.948883     13.888922     19.195731    584.511840
# min        0.010000     13.000000      3.000000      4.000000
# 25%        0.110000     62.000000     14.000000     11.000000
# 50%        0.290000     72.000000     24.000000     27.000000
# 75%        0.750000     80.000000     39.000000     88.000000
# max       82.530000     98.000000    113.000000  10665.000000

# %% [markdown]
# **Plot heatmap**

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df4.corr(),annot=True,cmap='viridis',linewidths=.5)
# Out:
# <ipython-input-11-b082358a44f3>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df4.corr(),annot=True,cmap='viridis',linewidths=.5)
# <Axes: >

# %% [markdown]
# **Drop the field and display**

# %%
filtered_df = df4.drop(['Global_Sales'], axis=1)
filtered_df.head(3)
# Out:
#                 Name Platform  Year_of_Release   Genre Publisher  NA_Sales  \
# 0         Wii Sports      Wii           2006.0  Sports  Nintendo     41.36
# 2     Mario Kart Wii      Wii           2008.0  Racing  Nintendo     15.68
# 3  Wii Sports Resort      Wii           2009.0  Sports  Nintendo     15.61
#
#    EU_Sales  JP_Sales  Other_Sales  Critic_Score  Critic_Count User_Score  \
# 0     28.96      3.77         8.45          76.0          51.0          8
# 2     12.76      3.79         3.29          82.0          73.0        8.3
# 3     10.93      3.28         2.95          80.0          73.0          8
#
#    User_Count Developer Rating
# 0       322.0  Nintendo      E
# 2       709.0  Nintendo      E
# 3       192.0  Nintendo      E

# %% [markdown]
# **Obtain a count of unique values**

# %%
filtered_df['Platform'].value_counts()
# Out:
# PS2     1161
# X360     877
# PS3      783
# PC       667
# XB       580
# Wii      491
# DS       468
# PSP      393
# GC       356
# GBA      241
# PS4      239
# XOne     159
# 3DS      157
# PS       153
# PSV      119
# WiiU      89
# DC        14
# Name: Platform, dtype: int64

# %% [markdown]
# **Maps specific platform names to new categories**

# %%
def platform(x):
  if x == 'PS2':
    return 'PS2'
  elif x == 'X360':
    return 'X360'
  elif x == 'PS3':
    return 'PS3'
  elif x == 'PC':
    return 'PC'
  else:
    return 'other_console'

filtered_df['Platform_new'] = filtered_df['Platform'].map(platform)

filtered_df.head(1)
# Out:
#          Name Platform  Year_of_Release   Genre Publisher  NA_Sales  EU_Sales  \
# 0  Wii Sports      Wii           2006.0  Sports  Nintendo     41.36     28.96
#
#    JP_Sales  Other_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 0      3.77         8.45          76.0          51.0          8       322.0
#
#   Developer Rating   Platform_new
# 0  Nintendo      E  other_console

# %%
filtered_df['Genre'].value_counts()
# Out:
# Action          1663
# Sports           965
# Shooter          882
# Role-Playing     718
# Racing           591
# Platform         407
# Misc             394
# Fighting         382
# Simulation       301
# Strategy         274
# Adventure        249
# Puzzle           121
# Name: Genre, dtype: int64

# %%
Developers_list = dict(filtered_df['Developer'].value_counts())
print(Developers_list)
# Out:
# {'EA Canada': 152, 'EA Sports': 145, 'Capcom': 128, 'Ubisoft': 104, 'Konami': 98, 'Ubisoft Montreal': 88, 'EA Tiburon': 86, 'Omega Force': 69, 'Nintendo': 68, 'Visual Concepts': 68, 'Electronic Arts': 68, "Traveller's Tales": 68, 'Vicarious Visions': 59, 'Codemasters': 58, 'Namco': 55, "Yuke's": 48, 'Midway': 44, 'TT Games': 43, 'Neversoft Entertainment': 43, 'Treyarch': 42, 'Maxis': 42, 'From Software': 41, 'Square Enix': 40, 'Eurocom Entertainment Software': 40, 'Sonic Team': 36, 'TOSE': 34, 'Radical Entertainment': 34, 'Harmonix Music Systems': 32, 'Arc System Works': 32, 'Sega': 32, 'Artificial Mind and Movement': 32, 'High Voltage Software': 31, 'Rebellion': 30, 'Gearbox Software': 27, 'Koei': 27, 'Climax Group': 26, 'Acclaim': 25, 'Rainbow Studios': 25, 'KCET': 25, 'SCEA San Diego Studios': 25, 'EA DICE': 24, 'Krome Studios': 24, 'Criterion Games': 24, 'EA Games': 24, 'Ubisoft Shanghai': 23, 'Griptonite Games': 23, 'Nippon Ichi Software': 22, 'Exient Entertainment': 22, 'BioWare': 22, 'CyberConnect2': 22, 'LucasArts': 21, 'EA Redwood Shores': 21, 'Volition Inc.': 21, 'Crystal Dynamics': 21, 'Team 17': 21, 'THQ': 21, 'Terminal Reality': 21, 'Blizzard Entertainment': 20, 'Io Interactive': 20, 'EA Bright Light': 20, 'Heavy Iron Studios': 20, 'Techland': 20, 'Dimps Corporation': 20, 'Creative Assembly': 20, 'SNK Playmore': 19, 'Milestone S.r.l': 19, 'Double Helix Games': 19, 'Eutechnyx': 19, 'Beenox': 19, 'WayForward': 18, 'Bandai Namco Games': 18, 'Ubisoft Montpellier': 18, 'Amaze Entertainment': 18, 'Kush Games': 18, 'Intelligent Systems': 18, 'Toys for Bob': 17, 'PlatinumGames': 17, 'Sumo Digital': 17, 'Tecmo': 17, 'SCE Japan Studio': 17, 'Spike': 17, 'Atlus': 17, 'Blitz Games': 17, 'Team Ninja': 17, '3DO': 17, 'Rockstar San Diego': 17, 'Raven Software': 16, 'Taito Corporation': 16, 'Avalanche Software': 16, 'Obsidian Entertainment': 16, 'Rare Ltd.': 16, 'Backbone Entertainment': 16, 'Digital Eclipse': 16, 'Pandemic Studios': 16, 'EA LA': 16, 'Black Box': 16, 'Level 5': 15, 'SquareSoft': 15, 'PopCap': 15, 'Z-Axis, Ltd.': 15, 'Infinity Ward': 15, 'Argonaut Games': 14, 'SCEA': 14, 'Ubisoft Paris': 14, 'Point of View': 14, 'Relic': 14, 'Rockstar North': 14, 'Visceral Games': 13, '2K Sports': 13, 'Mass Media': 13, 'Grasshopper Manufacture': 13, 'n-Space': 13, 'Firaxis Games': 13, 'HAL Labs': 13, 'Gust': 13, 'Next Level Games': 13, 'Blue Castle Games': 13, 'Digital Illusions': 13, 'FUN Labs': 13, 'Namco Bandai Games': 13, 'Valve Software': 13, 'Neverland': 12, '7 Studios': 12, 'Game Arts': 12, 'Blue Tongue Entertainment': 12, 'Vicious Cycle': 12, 'Kojima Productions': 12, 'SCEE London Studio': 12, 'Activision': 12, 'Cavia Inc.': 12, 'Asobo Studio': 12, 'Sting': 12, 'Ubisoft Quebec': 12, 'HB Studios Multimedia': 12, '989 Sports': 12, 'Edge of Reality': 12, 'Haemimont': 11, 'High Moon Studios': 11, 'Starbreeze': 11, 'Rocksteady Studios': 11, 'Gaijin Entertainment': 11, 'Hudson': 11, 'EA Black Box': 11, 'Bugbear': 11, 'Microsoft Game Studios': 11, 'Paradigm Entertainment': 11, 'Epic Games': 11, 'Free Radical Design': 11, 'Tri-Ace': 11, 'KCEJ': 11, 'Pipeworks Software, Inc.': 11, 'Racjin': 11, 'Ubisoft Romania': 11, 'Bandai': 11, 'Acquire': 11, 'Naughty Dog': 10, 'Treasure': 10, 'Pivotal Games': 10, 'Bizarre Creations': 10, 'Crytek': 10, 'Shaba Games': 10, 'Now Production': 10, 'Hudson Soft': 10, 'Frontier Developments': 10, 'Shiny Entertainment': 10, 'Natsume': 10, 'Spark Unlimited': 10, 'Monolith Productions': 10, 'FreeStyleGames': 10, 'Spike Chunsoft': 10, 'Acclaim Studios Cheltenham': 10, 'Avalanche Studios': 9, 'Piranha Bytes': 9, 'Digital Extremes': 9, 'Game Republic': 9, 'Papaya Studios': 9, 'Page 44 Studios': 9, 'Kuju Entertainment': 9, 'Compile Heart': 9, 'Sega AM2': 9, 'Camelot Software Planning': 9, 'Sports Interactive': 9, 'InXile Entertainment': 9, 'Bethesda Game Studios': 9, 'Image Epoch, Imageepoch': 9, 'Insomniac Games': 9, 'Day 1 Studios': 9, 'Rockstar Leeds': 9, '5TH Cell': 9, 'Falcom': 9, 'TT Fusion': 9, 'Snowbl ...

# %%
def developer(x):
  if x.find('EA') >= 0 or x.find('Electronic Arts') >= 0:
    return 'EA'
  elif x.find('Capcom') >= 0:
    return 'Capcom'
  elif x.find('Ubisoft') >= 0:
    return 'Ubisoft'
  elif x.find('Konami') >= 0:
    return 'Komani'
  elif x.find('Nitendo') >= 0:
    return 'Nitendo'
  else:
    return 'other_dev'
filtered_df['Developer_new'] = filtered_df['Developer'].map(developer)
filtered_df.head(1)
# Out:
#          Name Platform  Year_of_Release   Genre Publisher  NA_Sales  EU_Sales  \
# 0  Wii Sports      Wii           2006.0  Sports  Nintendo     41.36     28.96
#
#    JP_Sales  Other_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 0      3.77         8.45          76.0          51.0          8       322.0
#
#   Developer Rating   Platform_new Developer_new
# 0  Nintendo      E  other_console     other_dev

# %%
filtered_df['Rating'].value_counts()
# Out:
# T       2420
# E       2118
# M       1459
# E10+     946
# RP         2
# AO         1
# K-A        1
# Name: Rating, dtype: int64

# %%
def rating(x):
  if x == 'T':
    return 'T'
  elif x == 'E':
    return 'E'
  elif x == 'M':
    return 'M'
  elif x == 'E10+':
    return 'E10+'
  else:
    return 'other_rating'

filtered_df['Rating_new'] = filtered_df['Rating'].map(rating)

filtered_df.head(1)
# Out:
#          Name Platform  Year_of_Release   Genre Publisher  NA_Sales  EU_Sales  \
# 0  Wii Sports      Wii           2006.0  Sports  Nintendo     41.36     28.96
#
#    JP_Sales  Other_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 0      3.77         8.45          76.0          51.0          8       322.0
#
#   Developer Rating   Platform_new Developer_new Rating_new
# 0  Nintendo      E  other_console     other_dev          E

# %%
pub = dict(filtered_df['Publisher'].value_counts())

print(pub)
# Out:
# {'Electronic Arts': 960, 'Ubisoft': 498, 'Activision': 498, 'Sony Computer Entertainment': 316, 'THQ': 309, 'Nintendo': 292, 'Sega': 288, 'Take-Two Interactive': 274, 'Konami Digital Entertainment': 248, 'Namco Bandai Games': 241, 'Capcom': 200, 'Atari': 179, 'Microsoft Game Studios': 141, 'Warner Bros. Interactive Entertainment': 139, 'Tecmo Koei': 137, 'Square Enix': 135, 'Eidos Interactive': 125, 'Vivendi Games': 116, 'Codemasters': 113, 'Midway Games': 105, '505 Games': 80, 'Deep Silver': 77, 'Disney Interactive Studios': 75, 'LucasArts': 71, 'Unknown': 67, 'Acclaim Entertainment': 66, 'Nippon Ichi Software': 61, 'Rising Star Games': 52, 'Bethesda Softworks': 48, 'D3Publisher': 36, 'Focus Home Interactive': 31, 'Ignition Entertainment': 30, 'Empire Interactive': 28, 'Atlus': 25, 'Zoo Digital Publishing': 24, 'Kalypso Media': 24, 'Majesco Entertainment': 23, 'PQube': 22, 'TDK Mediactive': 21, 'SouthPeak Games': 21, 'Global Star': 20, 'Universal Interactive': 19, 'Virgin Interactive': 19, 'MTV Games': 17, '3DO': 15, 'Infogrames': 15, 'Paradox Interactive': 13, 'Ubisoft Annecy': 12, 'DTP Entertainment': 12, 'Sony Computer Entertainment Europe': 11, 'Crave Entertainment': 11, 'SCi': 11, 'Ghostlight': 10, 'BAM! Entertainment': 10, 'JoWood Productions': 10, 'Nordic Games': 10, 'Playlogic Game Factory': 10, 'Marvelous Interactive': 9, 'Play It': 9, 'SquareSoft': 9, 'Idea Factory': 8, 'Black Bean Games': 8, 'Gathering of Developers': 8, 'Metro 3D': 8, 'Interplay': 8, 'Spike': 8, 'City Interactive': 8, 'Midas Interactive Entertainment': 8, 'Sony Online Entertainment': 7, 'Microids': 7, 'Kemco': 7, 'Jaleco': 7, 'PopCap Games': 7, 'Destineer': 6, 'GungHo': 6, 'Aksys Games': 6, 'DreamCatcher Interactive': 6, 'Sting': 6, 'Activision Value': 6, 'Natsume': 5, 'Success': 5, 'NCSoft': 5, 'From Software': 5, 'Titus': 5, 'Game Factory': 5, 'Koch Media': 5, 'Takara Tomy': 4, 'Hudson Soft': 4, 'Sammy Corporation': 4, 'Evolved Games': 4, 'Screenlife': 4, 'Bigben Interactive': 4, 'Gamecock': 4, 'Milestone S.r.l.': 4, 'Touchstone': 4, 'Tomy Corporation': 4, 'Marvelous Entertainment': 4, 'RedOctane': 4, 'Yacht Club Games': 4, 'Enix Corporation': 4, 'Compile Heart': 4, 'Xseed Games': 4, 'Hip Interactive': 4, 'Telltale Games': 4, 'Milestone S.r.l': 4, 'Arc System Works': 4, 'Banpresto': 4, 'Enterbrain': 3, 'Indie Games': 3, 'FuRyu': 3, 'Swing! Entertainment': 3, 'GT Interactive': 3, 'Brash Entertainment': 3, 'Idea Factory International': 3, 'Valve Software': 3, 'Falcom Corporation': 3, 'Slightly Mad Studios': 3, 'Trion Worlds': 3, 'Insomniac Games': 3, 'Sony Computer Entertainment America': 3, 'Rage Software': 3, 'Avalon Interactive': 3, 'Zoo Games': 3, 'MC2 Entertainment': 3, 'Mastiff': 3, 'Taito': 3, 'The Adventure Company': 3, 'Destination Software, Inc': 3, 'Little Orbit': 3, 'Nobilis': 3, 'System 3 Arcade Software': 3, 'Wanadoo': 3, 'Genki': 3, 'Psygnosis': 3, 'Mastertronic': 3, 'Ascaron Entertainment GmbH': 2, 'Graffiti': 2, '1C Company': 2, 'Valcon Games': 2, 'Human Entertainment': 2, 'Tripwire Interactive': 2, 'Revolution Software': 2, 'Stainless Games': 2, 'Irem Software Engineering': 2, 'Tru Blu Entertainment': 2, 'Aspyr': 2, 'Sold Out': 2, 'bitComposer Games': 2, 'AQ Interactive': 2, 'NovaLogic': 2, 'Harmonix Music Systems': 2, 'Kadokawa Shoten': 2, 'Rondomedia': 2, 'Rebellion': 2, 'Xplosiv': 2, 'Mindscape': 2, 'Oxygen Interactive': 2, 'Gotham Games': 2, 'Agetec': 2, 'XS Games': 2, 'Gamebridge': 2, 'CCP': 2, 'Agatsuma Entertainment': 2, 'Mad Catz': 2, 'Gust': 2, 'Jester Interactive': 2, 'Square Enix ': 2, 'Funcom': 2, 'DHM Interactive': 1, 'Gearbox Software': 1, 'Global A Entertainment': 1, 'Iceberg Interactive': 1, 'Just Flight': 1, '2D Boy': 1, 'Fox Interactive': 1, 'Alternative Software': 1, 'Flashpoint Games': 1, 'Cloud Imperium Games Corporation': 1, '5pb': 1, 'Kool Kizz': 1, 'Rebellion Developments': 1, 'Hasbro Interactive': 1, 'Conspiracy Entertainment': 1, 'Max Five': 1, 'Team17 Software': 1, 'ESP': 1, 'Monte Christo Multimedia':  ...

# %%
def publisher(x):
  if x == 'Electronic Arts':
    return 'Electronic Arts'
  elif x == 'Activision':
    return 'Activision'
  elif x == 'Ubisoft':
    return 'Ubisoft'
  elif x == 'Sony Computer Entertainment':
    return 'Sony Computer Entertainment'
  elif x == 'Nintendo':
    return 'Nintendo'
  elif x == 'Konami Digital Entertainment':
    return 'Konami Digital Entertainment'
  else:
    return 'other_publisher'

filtered_df['Publisher_new'] = filtered_df['Publisher'].map(publisher)

filtered_df.head(1)
# Out:
#          Name Platform  Year_of_Release   Genre Publisher  NA_Sales  EU_Sales  \
# 0  Wii Sports      Wii           2006.0  Sports  Nintendo     41.36     28.96
#
#    JP_Sales  Other_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 0      3.77         8.45          76.0          51.0          8       322.0
#
#   Developer Rating   Platform_new Developer_new Rating_new Publisher_new
# 0  Nintendo      E  other_console     other_dev          E      Nintendo

# %%
new_df = filtered_df.drop(['Platform', 'Genre', 'Publisher', 'User_Score', 'Developer', 'Rating', 'Name'], axis = 1)

new_df.head(2)
# Out:
#    Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Critic_Score  \
# 0           2006.0     41.36     28.96      3.77         8.45          76.0
# 2           2008.0     15.68     12.76      3.79         3.29          82.0
#
#    Critic_Count  User_Count   Platform_new Developer_new Rating_new  \
# 0          51.0       322.0  other_console     other_dev          E
# 2          73.0       709.0  other_console     other_dev          E
#
#   Publisher_new
# 0      Nintendo
# 2      Nintendo

# %%
y = new_df['Other_Sales']

plat_new = pd.get_dummies(new_df['Platform_new'])
dev_new = pd.get_dummies(new_df['Developer_new'])
rat_new = pd.get_dummies(new_df['Rating_new'])
pub_new = pd.get_dummies(new_df['Publisher_new'])

X_ = pd.concat([new_df, plat_new, dev_new, rat_new, pub_new], axis = 1)
X = X_.drop(['Other_Sales', 'Platform_new', 'Developer_new', 'Rating_new', 'Publisher_new'], axis = 1)

X.head()
# Out:
#    Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Critic_Score  Critic_Count  \
# 0           2006.0     41.36     28.96      3.77          76.0          51.0
# 2           2008.0     15.68     12.76      3.79          82.0          73.0
# 3           2009.0     15.61     10.93      3.28          80.0          73.0
# 6           2006.0     11.28      9.14      6.50          89.0          65.0
# 7           2006.0     13.96      9.18      2.93          58.0          41.0
#
#    User_Count  PC  PS2  PS3  ...  M  T  other_rating  Activision  \
# 0       322.0   0    0    0  ...  0  0             0           0
# 2       709.0   0    0    0  ...  0  0             0           0
# 3       192.0   0    0    0  ...  0  0             0           0
# 6       431.0   0    0    0  ...  0  0             0           0
# 7       129.0   0    0    0  ...  0  0             0           0
#
#    Electronic Arts  Konami Digital Entertainment  Nintendo  \
# 0                0                             0         1
# 2                0                             0         1
# 3                0                             0         1
# 6                0                             0         1
# 7                0                             0         1
#
#    Sony Computer Entertainment  Ubisoft  other_publisher
# 0                            0        0                0
# 2                            0        0                0
# 3                            0        0                0
# 6                            0        0                0
# 7                            0        0                0
#
# [5 rows x 29 columns]

# %%
X.columns
# Out:
# Index(['Year_of_Release', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Count', 'PC', 'PS2', 'PS3', 'X360',
#        'other_console', 'Capcom', 'EA', 'Komani', 'Ubisoft', 'other_dev', 'E',
#        'E10+', 'M', 'T', 'other_rating', 'Activision', 'Electronic Arts',
#        'Konami Digital Entertainment', 'Nintendo',
#        'Sony Computer Entertainment', 'Ubisoft', 'other_publisher'],
#       dtype='object')

# %% [markdown]
# **Train the model**

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# **Linear Regression**

# %%
reg = LinearRegression()
model1 = reg.fit(Xtrain, ytrain)

# %% [markdown]
# **Evaluate the peformance**

# %%
print(reg.score(Xtrain, ytrain))
# Out:
# 0.5694420906947844

# %% [markdown]
# **Predict the score**

# %%
pred = reg.predict(Xtest)
r2_score = reg.score(Xtest,ytest)
print(r2_score)
# Out:
# 0.7608587648210825

# %% [markdown]
# **Save the model**

# %%
import pickle
saved_model = pickle.dump(reg, open('VideoGamesModel.pickle','wb'))
